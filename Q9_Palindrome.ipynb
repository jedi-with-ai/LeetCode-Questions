# %%
# Basic Solution
class Solution:
    def isPalindrome(self, x):
      string = str(x)
      reverse = string[::-1]
      if reverse == string :
        return True
      else:
        return False

solution1 = Solution()
solution1.isPalindrome("-121")
# Out:
# False

# %%
# Try doing it withour converting it into String
